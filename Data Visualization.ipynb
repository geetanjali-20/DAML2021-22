# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# %matplotlib inline  #wil lead to static image
# Out:
# UsageError: unrecognized arguments: #wil lead to static image

# %%
plt.plot?

# %%
y=np.linspace(1,10,20)

# %%
#sine wave
x=np.linspace(0,10,1000)
plt.plot(x,np.sin(x),color='red')

# %%
x=np.array([1,2,3,4,5,6,7,8])
y=np.array([1,4,9,16,25,36,49,64])
plt.plot(x,y,color='Green',linestyle='dashed')

# %%
#for grey scle 0-1  0:-black 1:-white  linestyle='dashed'

# %%
x=np.arange(40)
y=x**2
plt.plot(x,y,'g*')
plt.l

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 40 artists>

# %%
import pandas as pd
df=pd.read_csv("placement.csv")
df
plt.bar(df['cgpa'],df['package'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-722753a9d4c0> in <module>
#       2 df=pd.read_csv("placement.csv")
#       3 df
# ----> 4 plt.bar(df['cgpa'],df['package'])
#
# NameError: name 'plt' is not defined

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]>

# %%
plt.boxplot(df['cgpa'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xabf1a30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xabf1d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0xabf1880>],
#  'medians': [<matplotlib.lines.Line2D at 0xac0a118>],
#  'fliers': [<matplotlib.lines.Line2D at 0xac0a2c8>],
#  'means': []}

# %%
d=pd.read_csv("kc_house_data.csv")
d.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
plt.hist(d['floors'])
# Out:
# (array([1.068e+04, 0.000e+00, 1.910e+03, 0.000e+00, 8.241e+03, 0.000e+00,
#         1.610e+02, 0.000e+00, 6.130e+02, 8.000e+00]),
#  array([1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
print(sns.get_dataset_names(),end=" ")
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
df1=sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x='smoker',data=df1, palette='Set1',hue='sex')
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.scatterplot(data=df1,x='total_bill',y='tip',hue='time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.pairplot(df1,hue='time')

# %%
sns.set_style('darkgrid')

# %%
sns.displot(df1)

# %%
boolean masking

# %%
tips34=tips[tips['total_bill']<=40]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-caa65ded2f5f> in <module>
# ----> 1 tips34=tips[tips['total_bill']<=40]
#
# NameError: name 'tips' is not defined

# %%
sns.displot()
